# %% [markdown]
# <a href="https://colab.research.google.com/github/shahzaibedits23/AI-ML-DL-/blob/main/Assignment_(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Section 1: Basic Access & Info**
# 1. Display the first 5 rows of the dataset.
# 2. Display the last 3 rows of the dataset.
# 3. Show the column names and data types. 4. Count the number of missing values in each column.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/iris.csv')
print(df.head(5))
print()
print(df.tail(3))
print()
print(df.dtypes)
print()
print(df.columns)
print()
print(df.isnull().sum)
print()
print(df.info())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#      sepal_length  sepal_width  petal_length  petal_width         species
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#
# ...

# %% [markdown]
# ***Section 2: Selecting Rows & Columns***
#
# 5. Get only the Name and Sex columns.
# 6. Get the PassengerId, Name, and Fare columns of the first 10 rows.
# 7. Select all rows where Pclass = 1. 8. Select all rows where Sex = "female" and Survived = 1. 9. Select the Age of passengers whose Fare > 100.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Titanicdataset.csv')
print(df[['Name', 'Sex']])
print()
print(df.iloc[:10, [0, 1, 4]])
print()
print(df[df['Pclass'] == 1])
print()
print(df[(df['Sex'] == 'female') & (df['Survived'] == 1)])
print()
print(df[df['Fare'] > 100]['Age'])
# Out:
#                                              Name     Sex
# 0                                Kelly, Mr. James    male
# 1                Wilkes, Mrs. James (Ellen Needs)  female
# 2                       Myles, Mr. Thomas Francis    male
# 3                                Wirz, Mr. Albert    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..                                            ...     ...
# 413                            Spector, Mr. Woolf    male
# 414                  Oliva y Ocana, Dona. Fermina  female
# 415                  Saether, Mr. Simon Sivertsen    male
# 416                           Ware, Mr. Frederick    male
# 417                      Peter, Master. Michael J    male
#
# [418 rows x 2 columns]
#
#    PassengerId  Survived     Sex
# 0          892         0    male
# 1          893         1  female
# 2          894         0    male
# 3          895         0    male
# 4          896         1  female
# 5          897         0    male
# ...
