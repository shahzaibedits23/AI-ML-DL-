# %% [markdown]
# <a href="https://colab.research.google.com/github/shahzaibedits23/AI-ML-DL-/blob/main/Lab_(LR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np

data = {
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 3, 5, 6, 7, 8, 9, 10, 12],
    "Sleep_Hours": [7, 6.5, 6, 5.5, 5, 5, 4.5, 7, 6, 5.5, 5, 4.5, 4, 4, 3.5],
    "Attendance": [60, 65, 68, 72, 75, 78, 80, 62, 70, 74, 76, 79, 82, 85, 90],
    "Exam_Score": [50, 55, 60, 65, 70, 72, 75, 58, 67, 72, 74, 78, 82, 85, 90]
}

df = pd.DataFrame(data)

X = df[["Study_Hours", "Sleep_Hours", "Attendance"]]
y = df["Exam_Score"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on test set
y_pred = model.predict(X_test)

# ✅ Accuracy metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("\nModel Accuracy Metrics (30% Test Data):")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

# ✅ Make predictions on new (unseen) values
# new_data = pd.DataFrame({
#     "Study_Hours": [4, 6, 9, 11],
#     "Sleep_Hours": [6, 5.5, 4.5, 4],
#     "Attendance": [65, 75, 85, 90]
# })
# new_predictions = model.predict(new_data)


# ✅ Visualize the results
plt.scatter(y_test, y_pred, color="blue", label="Predictions")
plt.plot([y.min(), y.max()], [y.min(), y.max()], "r--", label="Perfect Fit Line")
plt.xlabel("Actual Exam Scores")
plt.ylabel("Predicted Exam Scores")
plt.title("Actual vs Predicted Exam Scores")
plt.legend()
plt.show()
# Out:
# Model Accuracy Metrics (30% Test Data):
# Mean Absolute Error (MAE): 1.42
# Mean Squared Error (MSE): 3.10
# Root Mean Squared Error (RMSE): 1.76
